# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.tabular import *
from fastai.vision import *
import pandas as pd

# %%
path = Path("/content")

# %%
df = pd.read_csv(path/"ML_CSV_PRE.csv", sep=";", index_col=0)

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0  50.0       1     168    62.0    110  ...     1      0     0       1       0
# 1  55.0       0     156    85.0    140  ...     1      0     0       1       1
# 2  52.0       0     165    64.0    130  ...     1      0     0       0       1
# 3  48.0       1     169    82.0    150  ...     1      0     0       1       1
# 4  48.0       0     156    56.0    100  ...     1      0     0       0       0
#
# [5 rows x 12 columns]

# %%
df.describe()
# Out:
#                 age        gender  ...        active        cardio
# count  69275.000000  69275.000000  ...  69275.000000  69275.000000
# mean      53.333612      0.348870  ...      0.803796      0.497481
# std        6.767572      0.476616  ...      0.397127      0.499997
# min       30.000000      0.000000  ...      0.000000      0.000000
# 25%       48.000000      0.000000  ...      1.000000      0.000000
# 50%       54.000000      0.000000  ...      1.000000      0.000000
# 75%       58.000000      1.000000  ...      1.000000      1.000000
# max       65.000000      1.000000  ...      1.000000      1.000000
#
# [8 rows x 12 columns]

# %%
dep_var = "cardio"
cat_names = ["gender", "cholesterol", "gluc", "smoke", "alco", "active"]
cont_names = ["height", "weight", "ap_hi", "ap_lo"]
procs = [FillMissing, Categorify, Normalize]

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
        .split_by_idx(valid_idx=range(6000,20000))
        .label_from_df(cols=dep_var)
        .databunch())

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>gender</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.5817</td>
#       <td>-0.4314</td>
#       <td>-0.4125</td>
#       <td>0.9206</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1.6018</td>
#       <td>0.1272</td>
#       <td>-0.4125</td>
#       <td>-0.1509</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>-0.3108</td>
#       <td>0.8953</td>
#       <td>-1.0229</td>
#       <td>-1.2223</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>-1.8409</td>
#       <td>-1.3391</td>
#       <td>-1.0229</td>
#       <td>0.9206</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>-0.5658</td>
#       <td>0.2669</td>
#       <td>0.0757</td>
#       <td>0.1706</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='89' class='' max='863', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.31% [89/863 00:00<00:08 0.9257]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-02
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.554810</td>
#       <td>0.561728</td>
#       <td>0.730143</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.568346</td>
#       <td>0.561646</td>
#       <td>0.728929</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0